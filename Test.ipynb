# %%
import pandas as pd
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
""" Train a decision tree classifier on the data and perform 10-fold cross-validation to compute the accuracy, precision, recall, and F1 score of the classifier. """
 

# Load the data

data=pd.read_csv('creditcard.csv')

from Classification_Technics import DT_modele
''
from Classification_Technics import Test_model

Test_model(data, DT_modele(data) , "SMOTE")
# Out:
# Original dataset shape Counter({0: 284315, 1: 492})
# Resampled dataset shape Counter({0: 284315, 1: 284315})
#        fit_time  score_time  test_accuracy  test_precision  test_recall  \
# 0     84.449074    0.057461       0.966692        0.938585     0.998734
# 1     84.816091    0.052479       0.996782        0.994503     0.999086
# 2     86.715604    0.053093       0.998030        0.996842     0.999226
# 3     84.824967    0.053072       0.998241        0.997087     0.999402
# 4     83.462592    0.056439       0.997767        0.996387     0.999156
# 5     85.688552    0.053462       0.992948        0.986903     0.999156
# 6     90.321751    0.053341       0.998681        0.997753     0.999613
# 7     87.090779    0.056019       0.998400        0.997542     0.999261
# 8     92.490587    0.053449       0.996289        0.993219     0.999402
# 9     94.030942    0.052526       0.566643        0.535732     0.999297
# Mean  87.389094    0.054134       0.951047        0.943455     0.999233
#
#        test_f1
# 0     0.967725
# 1     0.996789
# 2     0.998033
# 3     0.998243
# 4     0.997770
# 5     0.992992
# 6     0.998682
# 7     0.998401
# 8     0.996301
# 9     0.697518
# Mean  0.964245
#        fit_time  score_time  test_accuracy  test_precision  test_recall  \
# 0     84.449074    0.057461       0.966692        0.938585     0.998734
# 1     84.816091    0.052479       0.996782        0.994503     0.999086
# 2     86.715604    0.053093       0.998030        0.996842     0.999226
# 3     84.824967    0.053072       0.998241        0.997087     0.999402
# 4     83.462592    0.056439       0.997767        0.996387     0.999156
# 5     85.688552    0.053462       0.992948        0.986903     0.999156
# 6     90.321751    0.053341       0.998681        0.997753     0.999613
# 7     87.090779    0.056019       0.998400        0.997542     0.999261
# 8     92.490587    0.053449       0.996289        0.993219     0.999402
# 9     94.030942    0.052526       0.566643        0.535732     0.999297
# Mean  87.389094    0.054134       0.951047        0.943455     0.999233
#
#        test_f1
# 0     0.967725
# 1     0.996789
# 2     0.998033
# 3     0.998243
# 4     0.997770
# 5     0.992992
# 6     0.998682
# 7     0.998401
# 8     0.996301
# 9     0.697518
# Mean  0.964245

# %%
import Under_Sampling_Techniques as UT
import pandas as pd

data=pd.read_csv('creditcard.csv')

data['Class'] = data['Class'].astype(bool)



UT.TomekLinks_Tec(data)
# Out:
# Original dataset shape Counter({False: 284315, True: 492})
# Resampled dataset shape Counter({False: 284244, True: 492})
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284731  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284732  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284733  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284734  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284735  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284731 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284732  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284733  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284734  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284735 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284731  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284732  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284733 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284734 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284735  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 284731  False
# 284732  False
# 284733  False
# 284734  False
# 284735  False
#
# [284736 rows x 31 columns]

# %%
import Classification_Technics as CT
import pandas as pd


data=pd.read_csv('creditcard.csv')
CT.Test_model(data, CT.DT_modele(data) , "Undersampling")
# Out:
# Original dataset shape Counter({0: 284315, 1: 492})
# Resampled dataset shape Counter({0: 492, 1: 492})
#       fit_time  score_time  test_accuracy  test_precision  test_recall  \
# 0     0.025061    0.009044       0.929293        0.937500     0.918367
# 1     0.025689    0.007346       0.919192        0.886792     0.959184
# 2     0.024382    0.006795       0.949495        0.909091     1.000000
# 3     0.032481    0.006908       0.878788        0.931818     0.820000
# 4     0.030879    0.008490       0.816327        0.816327     0.816327
# 5     0.028304    0.007416       0.918367        0.901961     0.938776
# 6     0.025605    0.006974       0.938776        0.921569     0.959184
# 7     0.030542    0.006602       0.908163        0.916667     0.897959
# 8     0.022119    0.006394       0.918367        0.918367     0.918367
# 9     0.032699    0.007875       0.704082        0.884615     0.469388
# Mean  0.027776    0.007384       0.888085        0.902471     0.869755
#
#        test_f1
# 0     0.927835
# 1     0.921569
# 2     0.952381
# 3     0.872340
# 4     0.816327
# 5     0.920000
# 6     0.940000
# 7     0.907216
# 8     0.918367
# 9     0.613333
# Mean  0.878937
#       fit_time  score_time  test_accuracy  test_precision  test_recall  \
# 0     0.025061    0.009044       0.929293        0.937500     0.918367
# 1     0.025689    0.007346       0.919192        0.886792     0.959184
# 2     0.024382    0.006795       0.949495        0.909091     1.000000
# 3     0.032481    0.006908       0.878788        0.931818     0.820000
# 4     0.030879    0.008490       0.816327        0.816327     0.816327
# 5     0.028304    0.007416       0.918367        0.901961     0.938776
# 6     0.025605    0.006974       0.938776        0.921569     0.959184
# 7     0.030542    0.006602       0.908163        0.916667     0.897959
# 8     0.022119    0.006394       0.918367        0.918367     0.918367
# 9     0.032699    0.007875       0.704082        0.884615     0.469388
# Mean  0.027776    0.007384       0.888085        0.902471     0.869755
#
#        test_f1
# 0     0.927835
# 1     0.921569
# 2     0.952381
# 3     0.872340
# 4     0.816327
# 5     0.920000
# 6     0.940000
# 7     0.907216
# 8     0.918367
# 9     0.613333
# Mean  0.878937

# %%
#test grid search

import grid_search as GS
import pandas as pd


data=pd.read_csv('creditcard.csv')

GS.grid_search(data, "DT")
# Out:
# /home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 360 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/scohail/miniconda3/envs/myenv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.9993078  0.99924761 0.99926767
#  0.99933288 0.99926767 0.9992125  0.9992125  0.99920246 0.99917237
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.9989918  0.99904697 0.99920748
#  0.99928773 0.9992777  0.99926266 0.99917237 0.99924259 0.99918742
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.99898176 0.99919243 0.99912723
#  0.99922253 0.99919243 0.99923256 0.99925764 0.99925262 0.99919243
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.99904697 0.99907706 0.99911218
#  0.99927269 0.99926767 0.9992777  0.99925262 0.99928774 0.99918742]
#   warnings.warn(
# Best parameters for model DT : {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
